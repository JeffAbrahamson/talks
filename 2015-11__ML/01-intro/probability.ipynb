# %%
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(-100, 100, 201)
plt.plot(x, x * x)

# %% [markdown]
# # Example of sampling from a probability distribution.
#
# Note that we use the ppf (percent point function) = the inverse of the probability density function.  This is where it will likely arise most.

# %%
x = np.linspace(ss.norm.ppf(.01), ss.norm.ppf(.99), 100)
plt.plot(x, ss.norm.pdf(x))
plt.show()

# %% [markdown]
# # Running mean example
#
# First we want to generate a random sample, then we want to compute its sum and plot it.
#
# Questions:
# * What happens if we vary num_points?
# * What is the difference between the two plots?

# %%
num_points = 100
x = np.linspace(1, num_points, num_points)
sample = [ss.norm.rvs() for x in range(num_points)]
plt.plot(x, np.cumsum(sample))
plt.plot(x, [x / (i + 1) for i, x in enumerate(sample)])
